# %%
# !pip install pandas

# %%
import psycopg2
import pandas as pd

# %%
def create_database():
  
    conn=psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=Superpostgres@123")
    cur=conn.cursor()
    conn.set_session(autocommit=True)
    
    #creating database
    cur.execute("drop database if exists account")
    cur.execute("create database account")
    #closing default database connection
    conn.close()
    
    #connecting to account database
    conn=psycopg2.connect("host=127.0.0.1 dbname=account user=postgres password=Superpostgres@123")
    cur=conn.cursor()
    
    return cur, conn

# %%
def drop_tables(cur,conn):
    for query in drop_table_queries:
        cur.execute(query)
        cur.commit()

# %%
def create_tables(cur,conn):
     for query in create_table_queries:
        cur.execute(query)
        cur.commit()

# %%
WealthAccCountry=pd.read_csv("C:/Users/Lenovo/Downloads/Wealth-AccountsCountry.csv")

# %%
WealthAccCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
WealthAccCountry_less_col=WealthAccCountry[['Code', 'Short Name','Table Name', 'Region','Currency Unit']]

# %%
WealthAccCountry_less_col.head()
# Out:
#   Code Short Name Table Name                     Region      Currency Unit
# 0  ALB    Albania    Albania      Europe & Central Asia       Albanian lek
# 1  ARG  Argentina  Argentina  Latin America & Caribbean     Argentine peso
# 2  ARM    Armenia    Armenia      Europe & Central Asia      Armenian dram
# 3  AUS  Australia  Australia        East Asia & Pacific  Australian dollar
# 4  AUT    Austria    Austria      Europe & Central Asia               Euro

# %%
WealthAccSeries=pd.read_csv("C:/Users/Lenovo/Downloads/Wealth-AccountSeries.csv")

# %%
WealthAccSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
WealthAccSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
WealthAccSeries_less_col=WealthAccSeries[['Code','Source','Topic','Indicator Name']]

# %%
WealthAccSeries_less_col.head()
# Out:
#              Code                                             Source  \
# 0       NW.HCA.TO  World Bank. 2021. The Changing Wealth of Natio...
# 1       NW.HCA.PC  World Bank. 2021. The Changing Wealth of Natio...
# 2  NW.HCA.FEMP.PC  World Bank. 2021. The Changing Wealth of Natio...
# 3  NW.HCA.MEMP.PC  World Bank. 2021. The Changing Wealth of Natio...
# 4  NW.HCA.FEMA.PC  World Bank. 2021. The Changing Wealth of Natio...
#
#            Topic                                     Indicator Name
# 0  Human capital                  Human capital (constant 2018 US$)
# 1  Human capital       Human capital per capita (constant 2018 US$)
# 2  Human capital  Human capital per capita, employed female (con...
# 3  Human capital  Human capital per capita, employed male (const...
# 4  Human capital  Human capital per capita, female (constant 201...

# %%
WealthAccData=pd.read_csv("C:/Users/Lenovo/Downloads/Wealth-AccountData.csv")

# %%
WealthAccData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
WealthAccData_less_col=WealthAccData[['Country Name','Country Code', 'Series Name', 'Series Code']]

# %%
WealthAccData_less_col.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC

# %%
cur, conn=create_database()

# %%
AccCountry=("""create table if not exists AccCountry(
            Code VARCHAR ,
            Short_Name VARCHAR,
            Table_Name VARCHAR , 
            Region VARCHAR,
            Currency_Unit VARCHAR
           )""")

# %%
cur.execute(AccCountry)
conn.commit()

# %%
AccSeries=("""create table if not exists AccSeries(
          Code VARCHAR,
          Source VARCHAR,
          Topic VARCHAR,
          Indicater_Name VARCHAR)""")

# %%
cur.execute(AccSeries)
conn.commit()

# %%
AccData=("""create table if not exists AccData(
          Country_Name VARCHAR,
          Country_Code VARCHAR,
          Series_Name VARCHAR,
          Series_Code VARCHAR)""")

# %%
cur.execute(AccData)
conn.commit()

# %%
AccCountry_insert=("""Insert into AccCountry(
            Code,
            Short_Name,
            Table_Name , 
            Region ,
            Currency_Unit)
            values(%s,%s,%s,%s,%s)
            """)

# %%
for i ,row in WealthAccCountry_less_col.iterrows():
    cur.execute(AccCountry_insert,list(row))

# %%
AccSeries_insert=("""Insert into AccSeries(
          Code ,
          Source ,
          Topic ,
          Indicater_Name )
          values(%s,%s,%s,%s)
            """)

# %%
for i ,row in WealthAccSeries_less_col.iterrows():
    cur.execute(AccSeries_insert,list(row))

# %%
AccData_insert=("""Insert into AccData(
          Country_Name,
          Country_Code,
          Series_Name,
          Series_Code )
          values(%s,%s,%s,%s)
            """)

# %%
for i, row in WealthAccData_less_col.iterrows():
    cur.execute(AccData_insert,list(row))

# %%
conn.commit()
